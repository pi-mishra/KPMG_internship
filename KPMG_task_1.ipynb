# %% [markdown]
# <a href="https://colab.research.google.com/github/pi-mishra/KPMG_internship/blob/main/KPMG_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings = 'ignore'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Transactions= pd.read_excel("/content/drive/MyDrive/KPMG/KPMG_VI_New_raw_data_update_final (2).xlsx",sheet_name='Transactions')
NewCustomerList= pd.read_excel("/content/drive/MyDrive/KPMG/KPMG_VI_New_raw_data_update_final (2).xlsx",sheet_name='NewCustomerList')
CustomerDemographic= pd.read_excel("/content/drive/MyDrive/KPMG/KPMG_VI_New_raw_data_update_final (2).xlsx",sheet_name='CustomerDemographic')
CustomerAddress= pd.read_excel("/content/drive/MyDrive/KPMG/KPMG_VI_New_raw_data_update_final (2).xlsx",sheet_name='CustomerAddress')

# %% [markdown]
# # Transactions

# %%
#checking the first 5 rows

Transactions.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                     transaction_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1   Unnamed: 2           Unnamed: 3    Unnamed: 4    Unnamed: 5  \
# 0  product_id  customer_id     transaction_date  online_order  order_status
# 1           2         2950  2017-02-25 00:00:00         False      Approved
# 2           3         3120  2017-05-21 00:00:00          True      Approved
# 3          37          402  2017-10-16 00:00:00         False      Approved
# 4          88         3135  2017-08-31 00:00:00         False      Approved
#
# ...

# %%
# defining funtion to modify dataframe for analysis

def row_to_column(df):
    # Assign the first row as column names
    df.columns = df.iloc[0, :]

    # Drop the first row
    df = df.drop(0).reset_index(drop=True)

    # Remove the column names' index (name=0)
    df.columns.name = None

    return df  # Return the modified DataFrame

# %%
# modifying the dataframe

Transactions = row_to_column(Transactions)

# %%
# defining a function to get the datatype, null and duplicates

def dataframe_info(df):
    # Get data types of columns
    print("DATA TYPES")
    print(df.dtypes)
    print("-"*50)

    # Get the count of null values in each column
    print("Null Value Sum")
    print(df.isnull().sum())
    print("-"*50)

    # Get the count of duplicate rows
    print(f"Duplicate Rows = {df.duplicated().sum()}")

    return

# %%
# Getting the datatype , null and duplicates

dataframe_info(Transactions)
# Out:
# DATA TYPES
# transaction_id             object
# product_id                 object
# customer_id                object
# transaction_date           object
# online_order               object
# order_status               object
# brand                      object
# product_line               object
# product_class              object
# product_size               object
# list_price                 object
# standard_cost              object
# product_first_sold_date    object
# dtype: object
# --------------------------------------------------
# Null Value Sum
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# ...

# %% [markdown]
# ## Observations of transactions dataframe-
#
# * Data Types of the columns in the dataframe are not correct.
# * There are multiple missing values in dataframe
# * There are no duplicates

# %% [markdown]
# # NewCustomerList

# %%
#checking the first 5 rows

NewCustomerList.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                         first_name
# 1                                            Chickie
# 2                                              Morly
# 3                                            Ardelis
# 4                                             Lucine
#
#   Unnamed: 1 Unnamed: 2                           Unnamed: 3  \
# 0  last_name     gender  past_3_years_bike_related_purchases
# 1    Brister       Male                                   86
# 2     Genery       Male                                   69
# 3  Forrester     Female                                   10
# 4      Stutt     Female                                   64
#
#             Unnamed: 4                  Unnamed: 5             Unnamed: 6  \
# 0                  DOB                   job_title  job_industry_category
# ...

# %%
# modifying the dataframe

NewCustomerList = row_to_column(NewCustomerList)

# %%
# Getting the datatype , null and duplicates

dataframe_info(NewCustomerList)
# Out:
# DATA TYPES
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases     object
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                  object
# address                                 object
# postcode                                object
# state                                   object
# country                                 object
# property_valuation                      object
# NaN                                    float64
# NaN                                    float64
# NaN                                    float64
# NaN                                    float64
# ...

# %% [markdown]
# ## Observations of NewCustomerList dataframe-
#
# * Data Types of the columns in the dataframe are not correct.
# * There are multiple missing values in dataframe
# * There are no duplicates
# * There are invalid columns, which do not provide any information

# %% [markdown]
# # CustomerDemographic

# %%
#checking for the first 5 rows

CustomerDemographic.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3                           Unnamed: 4  \
# 0  first_name  last_name     gender  past_3_years_bike_related_purchases
# 1     Laraine  Medendorp          F                                   93
# 2         Eli    Bockman       Male                                   81
# 3       Arlin     Dearle       Male                                   61
# 4      Talbot        NaN       Male                                   33
#
#             Unnamed: 5              Unnamed: 6             Unnamed: 7  \
# ...

# %%
# modifying the dataframe

CustomerDemographic = row_to_column(CustomerDemographic)

# %%
# Getting the datatype , null and duplicates

dataframe_info(CustomerDemographic)
# Out:
# DATA TYPES
# customer_id                            object
# first_name                             object
# last_name                              object
# gender                                 object
# past_3_years_bike_related_purchases    object
# DOB                                    object
# job_title                              object
# job_industry_category                  object
# wealth_segment                         object
# deceased_indicator                     object
# default                                object
# owns_car                               object
# tenure                                 object
# dtype: object
# --------------------------------------------------
# Null Value Sum
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# ...

# %% [markdown]
# ## Observations of CustomerDemographic dataframe-
#
# * Data Types of the columns in the dataframe are not correct.
# * There are multiple missing values in dataframe
# * There are no duplicates
# * Gender is not mentioned correctly
# * There are invalid columns, which do not provide any information

# %% [markdown]
# ## CustomerAddress

# %%
#getting the first 5 rows of df

CustomerAddress.head()
# Out:
#   Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                        customer_id
# 1                                                  1
# 2                                                  2
# 3                                                  4
# 4                                                  5
#
#             Unnamed: 1 Unnamed: 2       Unnamed: 3 Unnamed: 4  \
# 0              address   postcode            state    country
# 1   060 Morning Avenue       2016  New South Wales  Australia
# 2  6 Meadow Vale Court       2153  New South Wales  Australia
# 3   0 Holy Cross Court       4211              QLD  Australia
# 4  17979 Del Mar Point       2448  New South Wales  Australia
#
#            Unnamed: 5
# 0  property_valuation
# 1                  10
# 2                  10
# 3                   9
# 4                   4

# %%
# modifying the dataframe

CustomerAddress = row_to_column(CustomerAddress)

# %%
# Getting the datatype , null and duplicates

dataframe_info(CustomerAddress)
# Out:
# DATA TYPES
# customer_id           object
# address               object
# postcode              object
# state                 object
# country               object
# property_valuation    object
# dtype: object
# --------------------------------------------------
# Null Value Sum
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64
# --------------------------------------------------
# Duplicate Rows = 0

# %% [markdown]
# ## Observations of CustomerAddress dataframe-
#
# * Data Types of the columns in the dataframe are not correct.
# * There are multiple missing values in dataframe
# * There are no duplicates
# * State is not mentioned correctly
